# %%
import numpy as np
import matplotlib.pyplot as plt
import pymc3 as pm
plt.style.use('seaborn-darkgrid')
# %matplotlib inline

# %%
intervals = {
    "average_household_size": {"lo": 4.2, "hi": 5.2},
    "percentage_of_transfers_invested": {"lo": 0.34, "hi": 0.44},
    "return_on_investment": {"lo": 0.05, "hi": 0.15},
    "baseline_annual_consumption_per_capita": {"lo": 250, "hi": 300},
    "duration_of_investment_benefits": {"lo": 10, "hi": 20},
    "percent_of_investment_returned_when_benefits_end": {"lo": 0.1, "hi": 0.3},
    "discount_from_negative_spillover": {"lo": 0.02, "hi": 0.15},
    "transfer_as_percentage_of_total_cost": {"lo": 0.5, "hi": 1},
    "discount_rate": {"lo": 0.01, "hi": 0.10},
    "value_of_increasing_ln_consumption_per_capita_per_annum": {"lo": 0.5, "hi": 3},
}

# %%
import importlib
import utility
importlib.reload(utility)

model = pm.Model()

parameters = { k: utility.log_normal_params_from_ci(**v) for k, v in intervals.items()}
log_normals = utility.log_normalify_parameters(model, parameters);

# %%
import cash
importlib.reload(cash)

with model:
    pm.Deterministic("value_per_dollar_transferred", cash.cash_transfers(**log_normals))

# %%
with model:
    trace = pm.sample(2000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [value_of_increasing_ln_consumption_per_capita_per_annum, discount_rate, transfer_as_percentage_of_total_cost, discount_from_negative_spillover, percent_of_investment_returned_when_benefits_end, duration_of_investment_benefits, baseline_annual_consumption_per_capita, return_on_investment, percentage_of_transfers_invested, average_household_size]
# Sampling 2 chains: 100%|██████████| 5000/5000 [00:11<00:00, 436.89draws/s]

# %%
pm.plot_posterior(trace, varnames=["value_per_dollar_transferred"], kde_plot=True);

# %%
import seaborn as sns
sns.set(style="darkgrid")
for rv in intervals:
    sns.jointplot(rv, "value_per_dollar_transferred", data=pm.trace_to_dataframe(trace), kind="reg")

# %%
from SALib.sample import saltelli
from SALib.analyze import sobol
from SALib.test_functions import Ishigami

# %%
problem = {
    "num_vars": len(parameters),
    "names": list(parameters.keys()),
    "bounds": [list(v) for v in parameters.values()],
    "dists": ["lognorm" for _ in parameters],
}
# Out:
# {'num_vars': 10, 'names': ['average_household_size', 'percentage_of_transfers_invested', 'return_on_investment', 'baseline_annual_consumption_per_capita', 'duration_of_investment_benefits', 'percent_of_investment_returned_when_benefits_end', 'discount_from_negative_spillover', 'transfer_as_percentage_of_total_cost', 'discount_rate', 'value_of_increasing_ln_consumption_per_capita_per_annum'], 'bounds': [[1.541871575438352, 0.06492191669780713], [-0.9498951067208801, 0.07837448423296882], [-2.446426129219936, 0.3339544232590008], [5.6126216962592235, 0.05542181802883723], [2.649158683274018, 0.21070178197089962], [-1.753278948659991, 0.3339544232590009], [-2.904571495157014, 0.6124870284891645], [-0.34657359027997264, 0.2107017819708996], [-3.4538776394910684, 0.6999361691719631], [0.20273255405408225, 0.5446562052299004]], 'dists': ['lognorm', 'lognorm', 'lognorm', 'lognorm', 'lognorm', 'lognorm', 'lognorm', 'lognorm', 'lognorm', 'lognorm']}

# %%
param_values = saltelli.sample(problem, 50, calc_second_order=False)
Y = np.array([cash.cash_transfers(*vs).eval() for vs in param_values])

# %% [markdown]
# ## Si = sobol.analyze(problem, Y, calc_second_order=False)
# print(len(parameters.keys()))
# print(Si)

# %%
np.mean(trace['value_per_dollar_transferred'])
pm.summary(trace)
# Out:
#                                                           mean         sd  \
# average_household_size                                4.689694   0.302957
# percentage_of_transfers_invested                      0.388416   0.029719
# return_on_investment                                  0.092070   0.031628
# baseline_annual_consumption_per_capita              274.130696  14.858696
# duration_of_investment_benefits                      14.426032   2.999662
# percent_of_investment_returned_when_benefits_end      0.181972   0.060798
# discount_from_negative_spillover                      0.066669   0.046332
# transfer_as_percentage_of_total_cost                  0.722566   0.156328
# discount_rate                                         0.040289   0.033737
# value_of_increasing_ln_consumption_per_capita_p...    1.430664   0.843113
# value_per_dollar_transferred                          0.003507   0.002381
#
#                                                     mc_error     hpd_2.5  \
# ...

# %%
help(pm.trace_to_dataframe(trace))
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  DataFrame(data=None, index=None, columns=None, dtype=None, copy=False)
#  |
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |
#  |      .. versionchanged :: 0.23.0
#  |         If data is a dict, argument order is maintained for Python 3.6
#  |         and later.
#  |
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to RangeIndex if
# ...

# %%
importlib.reload(utility)
S1, ST = utility.sa_to_dataframe(Si, parameters)
plt.figure()
sns.pointplot(x = "sensitivity", y = "variable", data=S1, join=False)
plt.figure()
sns.pointplot(x = "sensitivity", y = "variable", data=ST, join=False)
# Out:
#                                              variable  sensitivity  tag
# 0                              average_household_size    -0.000901   S1
# 1                              average_household_size    -0.004295  S1l
# 2                              average_household_size     0.002493  S1h
# 3                    percentage_of_transfers_invested    -0.003007   S1
# 4                    percentage_of_transfers_invested    -0.027309  S1l
# 5                    percentage_of_transfers_invested     0.021294  S1h
# 6                                return_on_investment     0.000007   S1
# 7                                return_on_investment    -0.000114  S1l
# 8                                return_on_investment     0.000129  S1h
# 9              baseline_annual_consumption_per_capita    -0.007272   S1
# 10             baseline_annual_consumption_per_capita    -0.024544  S1l
# 11             baseline_annual_consumption_per_capita     0.010000  S1h
# ...

# %%
import main
import worms
importlib.reload(main)
importlib.reload(utility)
importlib.reload(worms)

main.main(utility.all_staff_aggregates_to_params(main.params, 0.2))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [transfer_as_percentage_of_total_cost, discount_from_negative_spillover, percent_of_investment_returned_when_benefits_end, duration_of_investment_benefits, baseline_annual_consumption_per_capita, return_on_investment, percentage_of_transfers_invested, average_household_size, value_of_increasing_ln_consumption_per_capita_per_annum, discount_rate, additional_years_of_treatment_assigned_to_treatment_group_from_MK, replicability_adjustment_for_deworming, adjustment_for_years_of_treatment_in_MK_vs_charities_programs, adjustment_for_el_nino, multiplier_for_resource_sharing_within_households, duration_of_benefits_of_deworming, average_num_of_years_between_deworming_and_beginning_of_benefits, treatment_effect_on_ln_income_in_MK_study_population, total_additional_expected_value_from_leverage_and_funging, cost_per_capita_per_annum, worm_intensity_adjustment]
# ...
